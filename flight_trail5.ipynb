# %%
import os
import pandas as pd
os.chdir("C:\\Users\\Hp\\Downloads\\2004\\hourly")

# %%
weather_hour_data = pd.concat([pd.read_table(f , sep=",", encoding='unicode_escape',

                      na_values="'', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', 'N/A', 'NA', 'NULL', 'NaN', 'n/a', 'nan', 'null', '?', '#'")

                                 for f in os.listdir("C:\\Users\\Hp\\Downloads\\2004\\hourly")], ignore_index = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2903: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2903: DtypeWarning: Columns (1,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-7142f1c15b1a> in <module>()
#       3                       na_values="'', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', 'N/A', 'NA', 'NULL', 'NaN', 'n/a', 'nan', 'null', '?', '#'")
#       4
# ----> 5                                  for f in os.listdir("C:\\Users\\Hp\\Downloads\\2004\\hourly")], ignore_index = True)
#
# ...

# %%
weather_hour_data.shape

# %%
weather_hour_data.head(4)

# %%
os.chdir("C:\\Users\\Hp\\Downloads\\2004\\hpd")
weather_hpd_data = pd.concat([pd.read_table(f , sep=",", encoding='unicode_escape',

                      na_values="'', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND', '1.#QNAN', 'N/A', 'NA', 'NULL', 'NaN', 'n/a', 'nan', 'null', '?', '#'")

                                 for f in os.listdir("C:\\Users\\Hp\\Downloads\\2004\\hpd")], ignore_index = True)

# %%
os.chdir("C:\\Users\\Hp\\Downloads")
Flight_train=pd.read_csv("FlightDelay_Train-1550042794911.csv")

# %%
Flight_train.head(2)

# %%
Flight_train.shape

# %%
weather_hpd_data.head(2)

# %%
weather_hpd_data.shape

# %%
os.chdir("C:\\Users\\Hp\\Downloads\\all")

# %%
all_station_data= pd.read_csv("AllStationsData_PHD.txt",delimiter="|")

# %%
all_station_data.head(1)

# %%
all_station_data.shape

# %%
    Flight_train.isnull().sum(axis=0)

# %%
#item=pd.merge(Flight_train, all_station_data, how='inner', left_on=['Destination'], right_on=['AirportID'])

# %%
#item.shape
# Out:
# (7861, 20)

# %%
#item['ActualArrivalTimeStamp']=pd.to_datetime(item['ActualArrivalTimeStamp'])
#item['Actually_Arrived']=pd.to_datetime(item.ActualArrivalTimeStamp,format='%H%M').dt.strftime('%H:%M')

# %%
#item['Actually_Arrived']=item['Actually_Arrived'].str.replace(":","")

# %%
#item['Actually_Arrived']=item['Actually_Arrived'].astype('int64')

# %%
#item['ScheduledArrTime']=item['ScheduledArrTime'].astype('int64')

# %%
#item['FlightDelay']=0

#for i in range(0,len(item)):
 #   if item['Actually_Arrived'][i]-item['ScheduledArrTime'][i]>15 :
  #      item['FlightDelay'][i]= 1
   # else:
    #    item['FlightDelay'][i]=2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
#item.tail(1000)
# Out:
#        FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 6861  ORD_SNA_47270  2004     11          24          3              1253
# 6862  ATL_SNA_43426  2004     11          21          7              1745
# 6863  MSP_SNA_39075  2004     11          17          3              1136
# 6864  SLC_SNA_52486  2004      7           6          2              1110
# 6865  SMF_SNA_41623  2004      7          21          3              1040
# 6866  SFO_SNA_42580  2004     11           4          4              1031
# 6867  SJC_SNA_39869  2004     11          21          7              1700
# 6868  PHX_SNA_32217  2004      5           3          1               721
# 6869  ORD_SNA_29731  2004      5          16          7              1655
# 6870  OAK_SNA_49592  2004      7          21          3              1339
# 6871  SJC_SNA_28089  2004      9           5          7              1635
# 6872  SEA_SNA_44508  2004      7          16          5               605
# ...

# %%
weather_hour_data.head(4)
# Out:
#    WeatherStationID YearMonthDay  Time SkyConditions Visibility   DBT  \
# 0              3034     20040101    10        OVC095       10SM  30.0
# 1              3035     20040101    10        SCT110       10SM  43.0
# 2              3039     20040101    10        OVC002     0.25SM  14.0
# 3              3040     20040101    10           CLR       10SM  30.0
#
#    DewPointTemp  RelativeHumidityPercent WindSpeed WindDirection  \
# 0           7.0                     38.0         0           000
# 1          18.0                     37.0         0           000
# 2          12.0                     92.0         0           000
# 3          21.0                     69.0         9           250
#
#    WindGustValue  StationPressure
# 0            0.0            30.10
# 1            0.0            30.07
# 2            0.0            30.01
# 3            0.0            29.82

# %%
#item.columns
# Out:
# Index(['FlightNumber', 'Year', 'Month', 'DayofMonth', 'DayOfWeek',
#        'ScheduledDepTime', 'ScheduledArrTime', 'ScheduledTravelTime', 'Origin',
#        'Destination', 'Distance', 'ActualArrivalTimeStamp', 'WeatherStationID',
#        'AirportID', 'GroundHeight', 'StationHeight', 'BarometerHeight',
#        'Latitude', 'Longitude', 'TimeZone', 'Actually_Arrived', 'FlightDelay'],
#       dtype='object')

# %%
#weather_hour_data.columns
# Out:
# Index(['WeatherStationID', 'YearMonthDay', 'Time', 'SkyConditions',
#        'Visibility', 'DBT', 'DewPointTemp', 'RelativeHumidityPercent',
#        'WindSpeed', 'WindDirection', 'WindGustValue', 'StationPressure'],
#       dtype='object')

# %%
#weather_hour_data['WeatherStationID'].count()
# Out:
# 6485177

# %%
#weather_hour_data['WeatherStationID'].value_counts()
# Out:
# 24237    8116
# 25628    7081
# 93076    7040
# 25713    6908
# 24154    6858
# 25339    6748
# 4969     6674
# 14905    6640
# 3034     6572
# 4864     6570
# 4911     6567
# 4865     6566
# 4923     6559
# 4918     6558
# 4924     6557
# 4901     6556
# 4935     6556
# 4905     6556
# 4902     6556
# 4863     6555
# 4914     6553
# 4894     6552
# 4909     6551
# 4866     6551
# 3035     6549
# 4885     6543
# 14989    6540
# 4943     6538
# 4928     6536
# 4912     6535
#          ...
# 54735     427
# 26479     320
# 3037      286
# 22501     251
# 14780     249
# 24198     234
# 63823     234
# 26418     227
# 92813     223
# 93744     215
# 54974     214
# 94196     182
# 53128     168
# 23206     151
# 3973      150
# 93940     144
# 93092     140
# 53126     104
# 53130      95
# 63813      94
# 53963      73
# 92815      71
# 94061      66
# 53127      42
# 94163      41
# 13941      33
# 26414      23
# 26552       6
# 53983       4
# 63803       3
# ...

# %%
trail=Flight_train

# %%
trail.head(2)
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
#
#   ActualArrivalTimeStamp
# 0         20/09/04 11:54
# 1         19/11/04 18:55

# %%
import datetime as dt
trail["new_date"] = trail["DayofMonth"].map(str)+"-"+trail["Month"].map(str)+"-"+trail["Year"].map(str)

# %%
trail['ScheduledArrTime2']=pd.to_datetime(trail['ScheduledArrTime'],format='%H%M').dt.strftime('%H:%M')

# %%
trail.head()
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
# 2  SNA_LAS_44378  2004      5           4          2              1800
# 3  CLT_TPA_51502  2004      7           6          2              1400
# 4  MSP_ORD_44884  2004      9          23          4               830
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
# 2              1902                   62    SNA         LAS       226
# 3              1533                   93    CLT         TPA       508
# 4               946                   76    MSP         ORD       334
#
#   ActualArrivalTimeStamp    new_date ScheduledArrTime2
# 0         20/09/04 11:54   20-9-2004             11:54
# ...

# %%
trail["ActualArrivalTimeStamp_3"] = trail["new_date"] +" " + trail["ScheduledArrTime2"]

# %%
trail.head(30)
# Out:
#      FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0   BOS_CLE_29089  2004      9          20          1              1000
# 1   CLE_ATL_44346  2004     11          19          5              1440
# 2   SNA_LAS_44378  2004      5           4          2              1800
# 3   CLT_TPA_51502  2004      7           6          2              1400
# 4   MSP_ORD_44884  2004      9          23          4               830
# 5   CVG_GRR_45655  2004      9          26          7              1730
# 6   DFW_STL_53369  2004      5           5          3              1330
# 7   ACV_SFO_50785  2004      9          15          3               655
# 8   BHM_DFW_34260  2004      5          28          5              1425
# 9   DFW_PIT_33678  2004      9          11          6               847
# 10  GNV_ATL_31276  2004      7          18          7              1520
# 11  DFW_SJU_32640  2004      3          24          3              1521
# ...

# %%
trail['ActualArrivalTimeStamp']=trail['ActualArrivalTimeStamp'].str.replace("/","-")

# %%
trail.head(3)
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
# 2  SNA_LAS_44378  2004      5           4          2              1800
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
# 2              1902                   62    SNA         LAS       226
#
#   ActualArrivalTimeStamp    new_date ScheduledArrTime2  \
# 0         20-09-04 11:54   20-9-2004             11:54
# 1         19-11-04 18:55  19-11-2004             16:34
# 2         04-05-04 19:02    4-5-2004             19:02
#
#   ActualArrivalTimeStamp_3
# 0          20-9-2004 11:54
# 1         19-11-2004 16:34
# 2           4-5-2004 19:02

# %%
trail.dtypes
# Out:
# FlightNumber                object
# Year                         int64
# Month                        int64
# DayofMonth                   int64
# DayOfWeek                    int64
# ScheduledDepTime             int64
# ScheduledArrTime             int64
# ScheduledTravelTime          int64
# Origin                      object
# Destination                 object
# Distance                     int64
# ActualArrivalTimeStamp      object
# new_date                    object
# ScheduledArrTime2           object
# ActualArrivalTimeStamp_3    object
# dtype: object

# %%
trail['ActualArrivalTimeStamp']=pd.to_datetime(trail['ActualArrivalTimeStamp'])

# %%
trail['ActualArrivalTimeStamp_3']=pd.to_datetime(trail['ActualArrivalTimeStamp_3'])

# %%
trail["FlightDelay"] = trail["ActualArrivalTimeStamp"] - trail["ActualArrivalTimeStamp_3"]

# %%
trail.head(100)
# Out:
#      FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0   BOS_CLE_29089  2004      9          20          1              1000
# 1   CLE_ATL_44346  2004     11          19          5              1440
# 2   SNA_LAS_44378  2004      5           4          2              1800
# 3   CLT_TPA_51502  2004      7           6          2              1400
# 4   MSP_ORD_44884  2004      9          23          4               830
# 5   CVG_GRR_45655  2004      9          26          7              1730
# 6   DFW_STL_53369  2004      5           5          3              1330
# 7   ACV_SFO_50785  2004      9          15          3               655
# 8   BHM_DFW_34260  2004      5          28          5              1425
# 9   DFW_PIT_33678  2004      9          11          6               847
# 10  GNV_ATL_31276  2004      7          18          7              1520
# 11  DFW_SJU_32640  2004      3          24          3              1521
# ...

# %%
trail.dtypes
# Out:
# FlightNumber                         object
# Year                                  int64
# Month                                 int64
# DayofMonth                            int64
# DayOfWeek                             int64
# ScheduledDepTime                      int64
# ScheduledArrTime                      int64
# ScheduledTravelTime                   int64
# Origin                               object
# Destination                          object
# Distance                              int64
# ActualArrivalTimeStamp       datetime64[ns]
# new_date                             object
# ScheduledArrTime2                    object
# ActualArrivalTimeStamp_3     datetime64[ns]
# FlightDelay                 timedelta64[ns]
# dtype: object

# %%
trail['FlightDelay']=pd.to_datetime(trail['FlightDelay'])

# %%
trail.dtypes
# Out:
# FlightNumber                        object
# Year                                 int64
# Month                                int64
# DayofMonth                           int64
# DayOfWeek                            int64
# ScheduledDepTime                     int64
# ScheduledArrTime                     int64
# ScheduledTravelTime                  int64
# Origin                              object
# Destination                         object
# Distance                             int64
# ActualArrivalTimeStamp      datetime64[ns]
# new_date                            object
# ScheduledArrTime2                   object
# ActualArrivalTimeStamp_3    datetime64[ns]
# FlightDelay                 datetime64[ns]
# dtype: object

# %%
trail['FlightDelay']=pd.to_datetime(trail['FlightDelay'],format='%H%M').dt.strftime('%H:%M')

# %%
trail.head(2)
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
#
#   ActualArrivalTimeStamp    new_date ScheduledArrTime2  \
# 0    2004-09-20 11:54:00   20-9-2004             11:54
# 1    2004-11-19 18:55:00  19-11-2004             16:34
#
#   ActualArrivalTimeStamp_3 FlightDelay
# 0      2004-09-20 11:54:00       00:00
# 1      2004-11-19 16:34:00       02:21

# %%
trail['FlightDelay']=trail['FlightDelay'].str.replace(":","")

# %%
trail.head(2)
# Out:
#     FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0  BOS_CLE_29089  2004      9          20          1              1000
# 1  CLE_ATL_44346  2004     11          19          5              1440
#
#    ScheduledArrTime  ScheduledTravelTime Origin Destination  Distance  \
# 0              1154                  114    BOS         CLE       563
# 1              1634                  114    CLE         ATL       554
#
#   ActualArrivalTimeStamp    new_date ScheduledArrTime2  \
# 0    2004-09-20 11:54:00   20-9-2004             11:54
# 1    2004-11-19 18:55:00  19-11-2004             16:34
#
#   ActualArrivalTimeStamp_3 FlightDelay
# 0      2004-09-20 11:54:00        0000
# 1      2004-11-19 16:34:00        0221

# %%
trail['FlightDelay']=trail['FlightDelay'].astype('int64')

trail['FlightDelay']=trail['FlightDelay'].apply(lambda x: '1' if x>= 15 else '2')

# %%
trail.head(100)
# Out:
#      FlightNumber  Year  Month  DayofMonth  DayOfWeek  ScheduledDepTime  \
# 0   BOS_CLE_29089  2004      9          20          1              1000
# 1   CLE_ATL_44346  2004     11          19          5              1440
# 2   SNA_LAS_44378  2004      5           4          2              1800
# 3   CLT_TPA_51502  2004      7           6          2              1400
# 4   MSP_ORD_44884  2004      9          23          4               830
# 5   CVG_GRR_45655  2004      9          26          7              1730
# 6   DFW_STL_53369  2004      5           5          3              1330
# 7   ACV_SFO_50785  2004      9          15          3               655
# 8   BHM_DFW_34260  2004      5          28          5              1425
# 9   DFW_PIT_33678  2004      9          11          6               847
# 10  GNV_ATL_31276  2004      7          18          7              1520
# 11  DFW_SJU_32640  2004      3          24          3              1521
# ...

# %%
trail.FlightDelay.value_counts()
# Out:
# 2    6342
# 1    1519
# Name: FlightDelay, dtype: int64

# %%
trail.shape
# Out:
# (7861, 16)

# %%
weather_hour_data.dtypes
# Out:
# WeatherStationID             int64
# YearMonthDay                object
# Time                         int64
# SkyConditions               object
# Visibility                  object
# DBT                        float64
# DewPointTemp               float64
# RelativeHumidityPercent    float64
# WindSpeed                   object
# WindDirection               object
# WindGustValue              float64
# StationPressure            float64
# dtype: object

# %%
weather_hpd_data.dtypes
# Out:
# WeatherStationID      int64
# YearMonthDay          int64
# Time                  int64
# HourlyPrecip        float64
# dtype: object

# %%
weather_hpd_data['YearMonthDay']=weather_hpd_data['YearMonthDay'].astype(str)

# %%
new_df = pd.merge(weather_hour_data,weather_hpd_data ,how='left', left_on=['WeatherStationID','YearMonthDay','Time'], right_on = ['WeatherStationID','YearMonthDay','Time'])

# %%
print(new_df.shape)
print(new_df.tail())
# Out:
# (11516906, 13)
#           WeatherStationID YearMonthDay  Time  SkyConditions Visibility   DBT  \
# 11516901             64752     20051130   959            CLR       10SM  54.0
# 11516902             93167     20051130   959            CLR       10SM  51.0
# 11516903             93735     20051130   959         FEW080        7SM   NaN
# 11516904             94705     20051130   959  BKN003 OVC015        3SM   NaN
# 11516905             94950     20051130   959         OVC070       10SM  19.0
#
#           DewPointTemp  RelativeHumidityPercent WindSpeed WindDirection  \
# 11516901          45.0                     72.0         8           300
# 11516902          19.0                     28.0         0           000
# 11516903           NaN                      NaN         4           330
# 11516904           NaN                      NaN         6           300
# 11516905          14.0                     81.0         0           000
#
# ...

# %%
print(new_df.isnull().sum(axis=0))
# Out:
# WeatherStationID                  0
# YearMonthDay                      0
# Time                              0
# SkyConditions                296341
# Visibility                   274803
# DBT                         2262500
# DewPointTemp                2288896
# RelativeHumidityPercent     2295589
# WindSpeed                     65941
# WindDirection                 65982
# WindGustValue                 85796
# StationPressure             1435436
# HourlyPrecip               11458667
# dtype: int64

# %%
station_df = pd.merge(all_station_data,new_df,how="left",left_on=["WeatherStationID"],right_on=["WeatherStationID"])

# %%
station_df.isnull().sum()
# Out:
# WeatherStationID                  0
# AirportID                         0
# GroundHeight                      0
# StationHeight                     0
# BarometerHeight                   0
# Latitude                          0
# Longitude                         0
# TimeZone                          0
# YearMonthDay                     42
# Time                             42
# SkyConditions                296378
# Visibility                   274840
# DBT                         2259059
# DewPointTemp                2285455
# RelativeHumidityPercent     2292148
# WindSpeed                     65975
# WindDirection                 66018
# WindGustValue                 85830
# StationPressure             1435475
# HourlyPrecip               11455226
# dtype: int64

# %%
station_df.YearMonthDay[10590609] = "20040515"
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
station_df['date_'] =  pd.to_datetime(station_df['YearMonthDay'], format='%Y%m%d')
station_df['date_']= station_df.date_.astype(str)

# %%
Flight_train['new_date']= Flight_train.new_date.astype(str)

# %%
station_df["Time"] = station_df["Time"].astype(str)

# %%
station_df.Time= pd.to_numeric(station_df.Time, errors='coerce')

station_df['hours'] =station_df.Time.fillna(9999).astype(int)

# %%
station_df['hours']= station_df['hours'].astype(str)

# %%
length = 3
fill = '0'
station_df['hours'] = station_df["hours"].str.ljust(length,fill)
station_df['hours'] = station_df["hours"].str.rjust(4,"0")
station_df["hours_only"] = station_df["hours"].str[:2]

# %%
Flight_train.Time= pd.to_numeric(Flight_train.ScheduledDepTime, errors='coerce')

Flight_train['hours'] =Flight_train.Time.fillna(9999).astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
Flight_train['hours']= Flight_train['hours'].astype(str)

# %%
length = 3
fill = '0'
Flight_train['hours']= Flight_train["hours"].str.ljust(length,fill)
Flight_train['hours'] = Flight_train["hours"].str.rjust(4,"0")
Flight_train["hours_only"] = Flight_train["hours"].str[:2]

# %%
Flight_train.hours_only.value_counts()
# Out:
# 17    792
# 08    711
# 11    702
# 13    698
# 15    681
# 16    641
# 07    619
# 14    598
# 12    596
# 10    587
# 09    583
# 06    507
# 05     74
# 18     69
# 02      2
# 03      1
# Name: hours_only, dtype: int64

# %%
 train = pd.merge(Flight_train,station_df,how="left",left_on=["Destination","new_date","hours_only"],right_on=["AirportID","date_","hours_only"])
